# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyog2005/brain_tumorDetection_dip/blob/main/brainTumorDetectionUsing(VGG16).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
import os
import  numpy as np
import random
from PIL import Image,ImageEnhance

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input , Dense,Flatten,Dropout
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG16
from sklearn.utils import shuffle
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_dir = '/content/drive/MyDrive/mri images/Testing'
train_dir = '/content/drive/MyDrive/mri images/Training'

#training ka data
train_paths = []
train_labels = []
for label in os.listdir(train_dir):
  for img in os.listdir(os.path.join(train_dir,label)):
    train_paths.append(os.path.join(train_dir,label,img))
    train_labels.append(label)
train_path, train_label = shuffle(train_paths,train_labels)

#testing ka data
test_paths = []
test_labels = []
for label in os.listdir(test_dir):
  for img in os.listdir(os.path.join(test_dir,label)):
    test_paths.append(os.path.join(test_dir,label,img))
    test_labels.append(label)
test_paths,test_labels = shuffle(test_paths,test_labels)

# %%
test_paths
# Out:
# ['/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0016.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0282.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0159.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0232.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0310.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0302.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0263.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0323.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0203.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0073.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0238.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0225.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0260.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0070.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0112.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0167.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0216.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0104.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0151.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0265.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0275.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0252.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0172.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0084.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0092.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0276.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0039.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0161.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0241.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0168.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0254.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0189.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0094.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0047.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0237.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0280.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0246.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0256.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0100.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0281.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0363.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0210.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0084.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0149.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0289.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0199.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0231.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0109.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0079.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0132.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0170.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0048.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0276.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0117.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0279.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0047.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0064.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0119.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0036.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0298.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0174.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0267.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0057.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0058.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0029.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0134.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0390.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0282.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0133.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0129.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0307.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0093.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0227.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0143.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0157.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0012.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0105.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0282.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0368.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0203.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0137.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0226.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0190.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0180.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0035.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0199.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0068.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0123.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0230.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0205.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0198.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0394.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0243.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0026.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0078.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0289.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0033.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0303.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0248.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0380.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0242.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0154.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0163.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0041.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0286.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0341.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0197.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0179.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0295.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0214.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0209.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0010.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0217.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0271.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0162.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0203.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0123.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0144.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0185.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0268.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0270.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0074.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0258.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0300.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0245.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0052.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0209.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0120.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0278.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0174.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0022.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0085.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0222.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0375.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0327.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0350.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0166.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0187.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0022.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0220.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0195.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_
jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0169.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0292.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0123.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0049.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-meTr_0005.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0141.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0199.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0333.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0226.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0277.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0090.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0030.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0017.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0227.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0212.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0036.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0148.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0102.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0120.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0019.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0229.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0101.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0015.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0151.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0221.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0138.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0035.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0089.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0159.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0178.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0096.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0010.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0071.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0116.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0130.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0253.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0207.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0110.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0287.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0262.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0083.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0129.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0257.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0117.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0086.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0030.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0160.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0311.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0038.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0056.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0105.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0236.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0053.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0058.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0095.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0225.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0049.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0152.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0112.jpg',
#  '/content/drive/MyDrive/mri images/Testing/meningioma/Te-me_0168.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0263.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-piTr_0004.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0063.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0054.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0223.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0123.jpg',
#  '/content/drive/MyDrive/mri images/Testing/notumor/Te-no_0299.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0081.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0023.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0268.jpg',
#  '/content/drive/MyDrive/mri images/Testing/pituitary/Te-pi_0114.jpg',
#  '/content/drive/MyDrive/mri images/Testing/glioma/Te-gl_0262.jpg',
#  ...]

# %% [markdown]
# data visualize

# %%
import random
import matplotlib.pyplot as plt

random_indices = random.sample(range(len(train_paths)),10)


#figure ki display
fig, axes = plt.subplots(2,5,figsize=(15,6))
axes = axes.ravel()


for i,idx in enumerate(random_indices):
  img_path = train_paths[idx]
  img = Image.open(img_path)
  img = img.resize((224, 224))  # Resize to consistent size

    # Display image
  axes[i].imshow(img)
  axes[i].axis('off')  # Hide axis
    # Display class label in the second row
  axes[i].set_title(f"Label: {train_labels[idx]}", fontsize=10)

plt.tight_layout()
plt.show()

# %%
def augment_image(image):
    image = Image.fromarray(np.uint8(image))
    image = ImageEnhance.Brightness(image).enhance(random.uniform(0.8, 1.2))  # Random brightness
    image = ImageEnhance.Contrast(image).enhance(random.uniform(0.8, 1.2))  # Random contrast
    image = np.array(image) / 255.0  # Normalize pixel values to [0, 1]
    return image

# Load images and apply augmentation
def open_images(paths):
    images = []
    for path in paths:
        image = load_img(path, target_size=(IMAGE_SIZE, IMAGE_SIZE))
        image = augment_image(image)
        images.append(image)
    return np.array(images)

# Encoding labels (convert label names to integers)
def encode_label(labels):
    unique_labels = os.listdir(train_dir)  # Ensure unique labels are determined
    encoded = [unique_labels.index(label) for label in labels]
    return np.array(encoded)

# Data generator for batching
def datagen(paths, labels, batch_size=12, epochs=1):
    for _ in range(epochs):
        for i in range(0, len(paths), batch_size):
            batch_paths = paths[i:i + batch_size]
            batch_images = open_images(batch_paths)  # Open and augment images
            batch_labels = labels[i:i + batch_size]
            batch_labels = encode_label(batch_labels)  # Encode labels
            yield batch_images, batch_labels  # Yield the batch

# %% [markdown]
# https://youtu.be/MTQQnziWGQY?si=ZHIIcPADqaEN8WDV

# %%
IMAGE_SIZE = 128  # Image size (adjust based on your requirements)
base_model = VGG16(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False, weights='imagenet')

# Freeze all layers of the VGG16 base model
for layer in base_model.layers:
    layer.trainable = False

# Set the last few layers of the VGG16 base model to be trainable
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

# Build the final model
model = Sequential()
model.add(Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3)))  # Input layer
model.add(base_model)  # Add VGG16 base model
model.add(Flatten())  # Flatten the output of the base model
model.add(Dropout(0.3))  # Dropout layer for regularization
model.add(Dense(128, activation='relu'))  # Dense layer with ReLU activation
model.add(Dropout(0.2))  # Dropout layer for regularization
model.add(Dense(len(os.listdir(train_dir)), activation='softmax'))  # Output layer with softmax activation

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Parameters
batch_size = 20
steps = int(len(train_paths) / batch_size)  # Steps per epoch
epochs = 5

# Train the model
history = model.fit(datagen(train_paths, train_labels, batch_size=batch_size, epochs=epochs),
                    epochs=epochs, steps_per_epoch=steps)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/5
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3187s 11s/step - loss: 0.7420 - sparse_categorical_accuracy: 0.9279
# Epoch 2/5
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 38s 109ms/step - loss: 3.9004 - sparse_categorical_accuracy: 0.7446
# Epoch 3/5
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 104ms/step - loss: 3.9850 - sparse_categorical_accuracy: 0.7978
# Epoch 4/5
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 104ms/step - loss: 1.7262 - sparse_categorical_accuracy: 0.8729
# Epoch 5/5
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 104ms/step - loss: 3.3316 - sparse_categorical_accuracy: 0.8221

# %%
plt.figure(figsize=(8,4))
plt.grid(True)
plt.plot(history.history['sparse_categorical_accuracy'], '.g-', linewidth=2)
plt.plot(history.history['loss'], '.r-', linewidth=2)
plt.title('Model Training History')
plt.xlabel('epoch')
plt.xticks([x for x in range(epochs)])
plt.legend(['Accuracy', 'Loss'], loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns
from sklearn.preprocessing import label_binarize
from tensorflow.keras.models import load_model
import numpy as np

# 1. Prediction on test data
test_images = open_images(test_paths)  # Load and augment test images
test_labels_encoded = encode_label(test_labels)  # Encode the test labels

# Predict using the trained model
test_predictions = model.predict(test_images)

# 2. Classification Report
print("Classification Report:")
print(classification_report(test_labels_encoded, np.argmax(test_predictions, axis=1)))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 214ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       405
#            1       0.00      0.00      0.00       306
#            2       0.00      0.00      0.00       300
#            3       0.23      1.00      0.37       300
#
#     accuracy                           0.23      1311
#    macro avg       0.06      0.25      0.09      1311
# weighted avg       0.05      0.23      0.09      1311
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# 3. Confusion Matrix
conf_matrix = confusion_matrix(test_labels_encoded, np.argmax(test_predictions, axis=1))
print("Confusion Matrix:")
print(conf_matrix)

# Plot the Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=os.listdir(train_dir), yticklabels=os.listdir(train_dir))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Confusion Matrix:
# [[  0   0   0 405]
#  [  0   0   0 306]
#  [  0   0   0 300]
#  [  0   0   0 300]]

# %%
test_labels_bin = label_binarize(test_labels_encoded, classes=np.arange(len(os.listdir(train_dir))))
test_predictions_bin = test_predictions  # The predicted probabilities for each class

# Compute ROC curve and ROC AUC for each class
fpr, tpr, roc_auc = {}, {}, {}
for i in range(len(os.listdir(train_dir))):
    fpr[i], tpr[i], _ = roc_curve(test_labels_bin[:, i], test_predictions_bin[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(len(os.listdir(train_dir))):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # Diagonal line
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.show()

# %%
model.save('model.keras')

# %%
from tensorflow.keras.models import load_model
# Load the trained model
model = load_model('model.keras')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 22 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
from keras.preprocessing.image import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt

# Class labels
class_labels = ['pituitary', 'glioma', 'notumor', 'meningioma']

def detect_and_display(img_path, model, image_size=128):
    """
    Function to detect tumor and display results.
    If no tumor is detected, it displays "No Tumor".
    Otherwise, it shows the predicted tumor class and confidence.
    """
    try:
        # Load and preprocess the image
        img = load_img(img_path, target_size=(image_size, image_size))
        img_array = img_to_array(img) / 255.0  # Normalize pixel values
        img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

        # Make a prediction
        predictions = model.predict(img_array)
        predicted_class_index = np.argmax(predictions, axis=1)[0]
        confidence_score = np.max(predictions, axis=1)[0]

        # Determine the class
        if class_labels[predicted_class_index] == 'notumor':
            result = "No Tumor"
        else:
            result = f"Tumor: {class_labels[predicted_class_index]}"

        # Display the image with the prediction
        plt.imshow(load_img(img_path))
        plt.axis('off')
        plt.title(f"{result} (Confidence: {confidence_score * 100:.2f}%)")
        plt.show()

    except Exception as e:
        print("Error processing the image:", str(e))

# %%
image_path = '/content/drive/MyDrive/mri images/Testing/glioma/Te-glTr_0000.jpg'  # Provide the path to your new image
detect_and_display(image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
